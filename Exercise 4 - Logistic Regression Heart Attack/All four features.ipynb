# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('heart_attack.csv')
df
# Out:
#      heart_disease  age  gender  cp  trestbps  chol  fbs  restecg  thalach  \
# 0                0   63       1   1       145   233    1        2      150
# 1                1   67       1   4       160   286    0        2      108
# 2                1   67       1   4       120   229    0        2      129
# 3                0   37       1   3       130   250    0        0      187
# 4                0   41       0   2       130   204    0        2      172
# ..             ...  ...     ...  ..       ...   ...  ...      ...      ...
# 292              1   57       0   4       140   241    0        0      123
# 293              1   45       1   1       110   264    0        0      132
# 294              1   68       1   4       144   193    1        0      141
# 295              1   57       1   4       130   131    0        0      115
# 296              1   57       0   2       130   236    0        2      174
#
#      exang  oldpeak  slope  ca  thal
# ...

# %%
pairDataset = df[["heart_disease", "age", "trestbps", "chol", "thalach"]].copy()

pairDataset
# Out:
#      heart_disease  age  trestbps  chol  thalach
# 0                0   63       145   233      150
# 1                1   67       160   286      108
# 2                1   67       120   229      129
# 3                0   37       130   250      187
# 4                0   41       130   204      172
# ..             ...  ...       ...   ...      ...
# 292              1   57       140   241      123
# 293              1   45       110   264      132
# 294              1   68       144   193      141
# 295              1   57       130   131      115
# 296              1   57       130   236      174
#
# [297 rows x 5 columns]

# %%
sns.pairplot(data=pairDataset, hue="heart_disease", corner=True)
